# %% [markdown]
# # KNN – Machine Learning
# ## Gabriel Briones Sayeg A01222517
# ### Apr 2, 2019

# %%
library(class)
library(gmodels)

# %% [markdown]
# ## Read Dataset

# %%
df<-read.csv("0500_pima_indians_diabetes_data.csv", header=FALSE)

# %% [markdown]
# ## Visualize Dataset

# %%
normalize <- function(x) {
    return ((x - min(x)) / (max(x) - min(x)))
}
df_n <- as.data.frame(lapply(df[1:8], normalize))
summary(df_n)
# Out:
#        V1                V2               V3               V4
#  Min.   :0.00000   Min.   :0.0000   Min.   :0.0000   Min.   :0.0000
#  1st Qu.:0.05882   1st Qu.:0.4975   1st Qu.:0.5082   1st Qu.:0.0000
#  Median :0.17647   Median :0.5879   Median :0.5902   Median :0.2323
#  Mean   :0.22618   Mean   :0.6075   Mean   :0.5664   Mean   :0.2074
#  3rd Qu.:0.35294   3rd Qu.:0.7048   3rd Qu.:0.6557   3rd Qu.:0.3232
#  Max.   :1.00000   Max.   :1.0000   Max.   :1.0000   Max.   :1.0000
#        V5                V6               V7                V8
#  Min.   :0.00000   Min.   :0.0000   Min.   :0.00000   Min.   :0.0000
#  1st Qu.:0.00000   1st Qu.:0.4069   1st Qu.:0.07077   1st Qu.:0.0500
#  Median :0.03605   Median :0.4769   Median :0.12575   Median :0.1333
#  Mean   :0.09433   Mean   :0.4768   Mean   :0.16818   Mean   :0.2040
#  3rd Qu.:0.15041   3rd Qu.:0.5455   3rd Qu.:0.23409   3rd Qu.:0.3333
#  Max.   :1.00000   Max.   :1.0000   Max.   :1.00000   Max.   :1.0000

# %%
boxplot(df_n, las=2)
# Out:
# plot without title

# %% [markdown]
# ## Train model with 60% train data and 40% test data and k = 10

# %%
df_train <- df_n[1:460,]
df_test <- df_n[461:768,]
df_train_labels <- df[1:460, 9]
df_test_labels <- df[461:768, 9]

# %%
df_test_pred <- knn(train = df_train, test = df_test, cl = df_train_labels, k=10)

# %% [markdown]
# ### Confussion matrix shows 76% accuaracy

# %%
CrossTable(x = df_test_labels, y = df_test_pred, prop.chisq = FALSE)
# Out:
#
#    Cell Contents
# |-------------------------|
# |                       N |
# |           N / Row Total |
# |           N / Col Total |
# |         N / Table Total |
# |-------------------------|
#
#
# Total Observations in Table:  308
#
#
#                | df_test_pred
# df_test_labels |         0 |         1 | Row Total |
# ---------------|-----------|-----------|-----------|
#              0 |       181 |        34 |       215 |
#                |     0.842 |     0.158 |     0.698 |
#                |     0.801 |     0.415 |           |
#                |     0.588 |     0.110 |           |
# ---------------|-----------|-----------|-----------|
#              1 |        45 |        48 |        93 |
#                |     0.484 |     0.516 |     0.302 |
#                |     0.199 |     0.585 |           |
#                |     0.146 |     0.156 |           |
# ---------------|-----------|-----------|-----------|
#   Column Total |       226 |        82 |       308 |
# ...

# %% [markdown]
# ## Train model with 70% train data and 30% test data and k = 10

# %%
df_train <- df_n[1:534,]
df_test <- df_n[535:768,]
df_train_labels <- df[1:534, 9]
df_test_labels <- df[535:768, 9]

# %%
df_test_pred <- knn(train = df_train, test = df_test, cl = df_train_labels, k=10)

# %% [markdown]
# ### Confussion matrix shows 75% accuaracy

# %%
CrossTable(x = df_test_labels, y = df_test_pred, prop.chisq = FALSE)
# Out:
#
#    Cell Contents
# |-------------------------|
# |                       N |
# |           N / Row Total |
# |           N / Col Total |
# |         N / Table Total |
# |-------------------------|
#
#
# Total Observations in Table:  234
#
#
#                | df_test_pred
# df_test_labels |         0 |         1 | Row Total |
# ---------------|-----------|-----------|-----------|
#              0 |       137 |        17 |       154 |
#                |     0.890 |     0.110 |     0.658 |
#                |     0.774 |     0.298 |           |
#                |     0.585 |     0.073 |           |
# ---------------|-----------|-----------|-----------|
#              1 |        40 |        40 |        80 |
#                |     0.500 |     0.500 |     0.342 |
#                |     0.226 |     0.702 |           |
#                |     0.171 |     0.171 |           |
# ---------------|-----------|-----------|-----------|
#   Column Total |       177 |        57 |       234 |
# ...

# %% [markdown]
# ## Train model with 80% train data and 20% test data and k = 10

# %%
df_train <- df_n[1:614,]
df_test <- df_n[615:768,]
df_train_labels <- df[1:614, 9]
df_test_labels <- df[615:768, 9]

# %%
df_test_pred <- knn(train = df_train, test = df_test, cl = df_train_labels, k=10)

# %% [markdown]
# ###  Confusion matrix shows 71% accuaracy

# %%
CrossTable(x = df_test_labels, y = df_test_pred, prop.chisq = FALSE)
# Out:
#
#    Cell Contents
# |-------------------------|
# |                       N |
# |           N / Row Total |
# |           N / Col Total |
# |         N / Table Total |
# |-------------------------|
#
#
# Total Observations in Table:  154
#
#
#                | df_test_pred
# df_test_labels |         0 |         1 | Row Total |
# ---------------|-----------|-----------|-----------|
#              0 |        87 |        12 |        99 |
#                |     0.879 |     0.121 |     0.643 |
#                |     0.744 |     0.324 |           |
#                |     0.565 |     0.078 |           |
# ---------------|-----------|-----------|-----------|
#              1 |        30 |        25 |        55 |
#                |     0.545 |     0.455 |     0.357 |
#                |     0.256 |     0.676 |           |
#                |     0.195 |     0.162 |           |
# ---------------|-----------|-----------|-----------|
#   Column Total |       117 |        37 |       154 |
# ...

# %% [markdown]
# ## Train model with 60% train data and 40% test data and k = 18

# %%
df_train <- df_n[1:460,]
df_test <- df_n[461:768,]
df_train_labels <- df[1:460, 9]
df_test_labels <- df[461:768, 9]

# %%
df_test_pred <- knn(train = df_train, test = df_test, cl = df_train_labels, k=18)

# %% [markdown]
# ### Confussion matrix shows 78% accuaracy

# %%
CrossTable(x = df_test_labels, y = df_test_pred, prop.chisq = FALSE)
# Out:
#
#    Cell Contents
# |-------------------------|
# |                       N |
# |           N / Row Total |
# |           N / Col Total |
# |         N / Table Total |
# |-------------------------|
#
#
# Total Observations in Table:  308
#
#
#                | df_test_pred
# df_test_labels |         0 |         1 | Row Total |
# ---------------|-----------|-----------|-----------|
#              0 |       193 |        22 |       215 |
#                |     0.898 |     0.102 |     0.698 |
#                |     0.818 |     0.306 |           |
#                |     0.627 |     0.071 |           |
# ---------------|-----------|-----------|-----------|
#              1 |        43 |        50 |        93 |
#                |     0.462 |     0.538 |     0.302 |
#                |     0.182 |     0.694 |           |
#                |     0.140 |     0.162 |           |
# ---------------|-----------|-----------|-----------|
#   Column Total |       236 |        72 |       308 |
# ...

# %% [markdown]
# ## Train model with 70% train data and 30% test data and k = 18

# %%
df_train <- df_n[1:534,]
df_test <- df_n[535:768,]
df_train_labels <- df[1:534, 9]
df_test_labels <- df[535:768, 9]

# %%
df_test_pred <- knn(train = df_train, test = df_test, cl = df_train_labels, k=18)

# %% [markdown]
# ### Confussion matrix shows 76% accuaracy

# %%
CrossTable(x = df_test_labels, y = df_test_pred, prop.chisq = FALSE)
# Out:
#
#    Cell Contents
# |-------------------------|
# |                       N |
# |           N / Row Total |
# |           N / Col Total |
# |         N / Table Total |
# |-------------------------|
#
#
# Total Observations in Table:  234
#
#
#                | df_test_pred
# df_test_labels |         0 |         1 | Row Total |
# ---------------|-----------|-----------|-----------|
#              0 |       138 |        16 |       154 |
#                |     0.896 |     0.104 |     0.658 |
#                |     0.798 |     0.262 |           |
#                |     0.590 |     0.068 |           |
# ---------------|-----------|-----------|-----------|
#              1 |        35 |        45 |        80 |
#                |     0.438 |     0.562 |     0.342 |
#                |     0.202 |     0.738 |           |
#                |     0.150 |     0.192 |           |
# ---------------|-----------|-----------|-----------|
#   Column Total |       173 |        61 |       234 |
# ...

# %% [markdown]
# ## Train model with 80% train data and 20% test data and k = 18

# %%
df_train <- df_n[1:614,]
df_test <- df_n[615:768,]
df_train_labels <- df[1:614, 9]
df_test_labels <- df[615:768, 9]

# %%
df_test_pred <- knn(train = df_train, test = df_test, cl = df_train_labels, k=18)

# %% [markdown]
# ###  Confusion matrix shows 77% accuaracy

# %%
CrossTable(x = df_test_labels, y = df_test_pred, prop.chisq = FALSE)
# Out:
#
#    Cell Contents
# |-------------------------|
# |                       N |
# |           N / Row Total |
# |           N / Col Total |
# |         N / Table Total |
# |-------------------------|
#
#
# Total Observations in Table:  154
#
#
#                | df_test_pred
# df_test_labels |         0 |         1 | Row Total |
# ---------------|-----------|-----------|-----------|
#              0 |        91 |         8 |        99 |
#                |     0.919 |     0.081 |     0.643 |
#                |     0.752 |     0.242 |           |
#                |     0.591 |     0.052 |           |
# ---------------|-----------|-----------|-----------|
#              1 |        30 |        25 |        55 |
#                |     0.545 |     0.455 |     0.357 |
#                |     0.248 |     0.758 |           |
#                |     0.195 |     0.162 |           |
# ---------------|-----------|-----------|-----------|
#   Column Total |       121 |        33 |       154 |
# ...

# %% [markdown]
# ## Train model with 60% train data and 40% test data and k = 28

# %%
df_train <- df_n[1:460,]
df_test <- df_n[461:768,]
df_train_labels <- df[1:460, 9]
df_test_labels <- df[461:768, 9]

# %%
df_test_pred <- knn(train = df_train, test = df_test, cl = df_train_labels, k=28)

# %% [markdown]
# ### Confussion matrix shows 80% accuaracy

# %%
CrossTable(x = df_test_labels, y = df_test_pred, prop.chisq = FALSE)
# Out:
#
#    Cell Contents
# |-------------------------|
# |                       N |
# |           N / Row Total |
# |           N / Col Total |
# |         N / Table Total |
# |-------------------------|
#
#
# Total Observations in Table:  308
#
#
#                | df_test_pred
# df_test_labels |         0 |         1 | Row Total |
# ---------------|-----------|-----------|-----------|
#              0 |       197 |        18 |       215 |
#                |     0.916 |     0.084 |     0.698 |
#                |     0.814 |     0.273 |           |
#                |     0.640 |     0.058 |           |
# ---------------|-----------|-----------|-----------|
#              1 |        45 |        48 |        93 |
#                |     0.484 |     0.516 |     0.302 |
#                |     0.186 |     0.727 |           |
#                |     0.146 |     0.156 |           |
# ---------------|-----------|-----------|-----------|
#   Column Total |       242 |        66 |       308 |
# ...

# %% [markdown]
# ## Train model with 70% train data and 30% test data and k = 28

# %%
df_train <- df_n[1:534,]
df_test <- df_n[535:768,]
df_train_labels <- df[1:534, 9]
df_test_labels <- df[535:768, 9]

# %%
df_test_pred <- knn(train = df_train, test = df_test, cl = df_train_labels, k=28)

# %% [markdown]
# ### Confussion matrix shows 77% accuaracy

# %%
CrossTable(x = df_test_labels, y = df_test_pred, prop.chisq = FALSE)
# Out:
#
#    Cell Contents
# |-------------------------|
# |                       N |
# |           N / Row Total |
# |           N / Col Total |
# |         N / Table Total |
# |-------------------------|
#
#
# Total Observations in Table:  234
#
#
#                | df_test_pred
# df_test_labels |         0 |         1 | Row Total |
# ---------------|-----------|-----------|-----------|
#              0 |       143 |        11 |       154 |
#                |     0.929 |     0.071 |     0.658 |
#                |     0.777 |     0.220 |           |
#                |     0.611 |     0.047 |           |
# ---------------|-----------|-----------|-----------|
#              1 |        41 |        39 |        80 |
#                |     0.512 |     0.487 |     0.342 |
#                |     0.223 |     0.780 |           |
#                |     0.175 |     0.167 |           |
# ---------------|-----------|-----------|-----------|
#   Column Total |       184 |        50 |       234 |
# ...

# %% [markdown]
# ## Train model with 80% train data and 20% test data and k = 28

# %%
df_train <- df_n[1:614,]
df_test <- df_n[615:768,]
df_train_labels <- df[1:614, 9]
df_test_labels <- df[615:768, 9]

# %%
df_test_pred <- knn(train = df_train, test = df_test, cl = df_train_labels, k=28)

# %% [markdown]
# ###  Confusion matrix shows 75% accuaracy

# %%
CrossTable(x = df_test_labels, y = df_test_pred, prop.chisq = FALSE)
# Out:
#
#    Cell Contents
# |-------------------------|
# |                       N |
# |           N / Row Total |
# |           N / Col Total |
# |         N / Table Total |
# |-------------------------|
#
#
# Total Observations in Table:  154
#
#
#                | df_test_pred
# df_test_labels |         0 |         1 | Row Total |
# ---------------|-----------|-----------|-----------|
#              0 |        92 |         7 |        99 |
#                |     0.929 |     0.071 |     0.643 |
#                |     0.754 |     0.219 |           |
#                |     0.597 |     0.045 |           |
# ---------------|-----------|-----------|-----------|
#              1 |        30 |        25 |        55 |
#                |     0.545 |     0.455 |     0.357 |
#                |     0.246 |     0.781 |           |
#                |     0.195 |     0.162 |           |
# ---------------|-----------|-----------|-----------|
#   Column Total |       122 |        32 |       154 |
# ...

# %% [markdown]
# ## Train model with 60% train data and 40% test data and k = 38

# %%
df_train <- df_n[1:460,]
df_test <- df_n[461:768,]
df_train_labels <- df[1:460, 9]
df_test_labels <- df[461:768, 9]

# %%
df_test_pred <- knn(train = df_train, test = df_test, cl = df_train_labels, k=38)

# %% [markdown]
# ### Confussion matrix shows 79% accuaracy

# %%
CrossTable(x = df_test_labels, y = df_test_pred, prop.chisq = FALSE)
# Out:
#
#    Cell Contents
# |-------------------------|
# |                       N |
# |           N / Row Total |
# |           N / Col Total |
# |         N / Table Total |
# |-------------------------|
#
#
# Total Observations in Table:  308
#
#
#                | df_test_pred
# df_test_labels |         0 |         1 | Row Total |
# ---------------|-----------|-----------|-----------|
#              0 |       202 |        13 |       215 |
#                |     0.940 |     0.060 |     0.698 |
#                |     0.811 |     0.220 |           |
#                |     0.656 |     0.042 |           |
# ---------------|-----------|-----------|-----------|
#              1 |        47 |        46 |        93 |
#                |     0.505 |     0.495 |     0.302 |
#                |     0.189 |     0.780 |           |
#                |     0.153 |     0.149 |           |
# ---------------|-----------|-----------|-----------|
#   Column Total |       249 |        59 |       308 |
# ...

# %% [markdown]
# ## Train model with 70% train data and 30% test data and k = 38

# %%
df_train <- df_n[1:534,]
df_test <- df_n[535:768,]
df_train_labels <- df[1:534, 9]
df_test_labels <- df[535:768, 9]

# %%
df_test_pred <- knn(train = df_train, test = df_test, cl = df_train_labels, k=38)

# %% [markdown]
# ### Confussion matrix shows 79% accuaracy

# %%
CrossTable(x = df_test_labels, y = df_test_pred, prop.chisq = FALSE)
# Out:
#
#    Cell Contents
# |-------------------------|
# |                       N |
# |           N / Row Total |
# |           N / Col Total |
# |         N / Table Total |
# |-------------------------|
#
#
# Total Observations in Table:  234
#
#
#                | df_test_pred
# df_test_labels |         0 |         1 | Row Total |
# ---------------|-----------|-----------|-----------|
#              0 |       147 |         7 |       154 |
#                |     0.955 |     0.045 |     0.658 |
#                |     0.774 |     0.159 |           |
#                |     0.628 |     0.030 |           |
# ---------------|-----------|-----------|-----------|
#              1 |        43 |        37 |        80 |
#                |     0.537 |     0.463 |     0.342 |
#                |     0.226 |     0.841 |           |
#                |     0.184 |     0.158 |           |
# ---------------|-----------|-----------|-----------|
#   Column Total |       190 |        44 |       234 |
# ...

# %% [markdown]
# ## Train model with 80% train data and 20% test data and k = 38

# %%
df_train <- df_n[1:614,]
df_test <- df_n[615:768,]
df_train_labels <- df[1:614, 9]
df_test_labels <- df[615:768, 9]

# %%
df_test_pred <- knn(train = df_train, test = df_test, cl = df_train_labels, k=38)

# %% [markdown]
# ###  Confusion matrix shows 77% accuaracy

# %%
CrossTable(x = df_test_labels, y = df_test_pred, prop.chisq = FALSE)
# Out:
#
#    Cell Contents
# |-------------------------|
# |                       N |
# |           N / Row Total |
# |           N / Col Total |
# |         N / Table Total |
# |-------------------------|
#
#
# Total Observations in Table:  154
#
#
#                | df_test_pred
# df_test_labels |         0 |         1 | Row Total |
# ---------------|-----------|-----------|-----------|
#              0 |        94 |         5 |        99 |
#                |     0.949 |     0.051 |     0.643 |
#                |     0.758 |     0.167 |           |
#                |     0.610 |     0.032 |           |
# ---------------|-----------|-----------|-----------|
#              1 |        30 |        25 |        55 |
#                |     0.545 |     0.455 |     0.357 |
#                |     0.242 |     0.833 |           |
#                |     0.195 |     0.162 |           |
# ---------------|-----------|-----------|-----------|
#   Column Total |       124 |        30 |       154 |
# ...
